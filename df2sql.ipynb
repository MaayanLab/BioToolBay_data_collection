# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
only_main_tools = pd.read_table('ALL_DATA/DATABASE/TOOLS/DATABASE_main_tools.txt', keep_default_na=False)

# %%
all_articles_tools = pd.read_table('ALL_DATA/DATABASE/TOOLS/DATABASE_all_tools_articles.txt', keep_default_na=False)

# %%
# Step 1: TABLE WITH ALTMETRIC SCORE INFORMATION: 
altmetric_data =DataFrame()
altmetric_data = all_articles_tools[["altmetric_score", "altmetric_link"]]
altmetric_data =altmetric_data.drop_duplicates(subset="altmetric_score")
altmetric_data = altmetric_data.sort_values(by='altmetric_score', ascending=True)
altmetric_data = altmetric_data.rename(index=str, columns={"altmetric_score": "score", "altmetric_link": "badge_link"})

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:PASSWORD@localhost/BioToolBay')
altmetric_data.to_sql(name="altmetrics", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
#altmetric_data

# %%
# Step 2: TABLE WITH JOURNAL INFORMATION:

# %%
journals =DataFrame(columns=["id", "name", "URL_main","URL_logo"])

# %%
journals.id=[1,2,3,4]
journals.name=["Nucleic Acids Research", "Bioinformatics Oxford", "BMC Bioinformatics","Database Oxford"]
journals.URL_main=["https://academic.oup.com/nar", "https://academic.oup.com/bioinformatics", "https://bmcbioinformatics.biomedcentral.com/","https://academic.oup.com/database"]
journals.URL_logo=["http://epichembio.eu/wp-content/uploads/2016/04/nucleic-acid-research.gif", "https://oup.silverchair-cdn.com/UI/app/svg/umbrella/oxford-academic-logo.svg", "https://upload.wikimedia.org/wikipedia/commons/2/2a/BMC_Bioinformatics_Logo.jpg", "https://oup.silverchair-cdn.com/UI/app/svg/umbrella/oxford-academic-logo.svg"]

# %%
#journals

# %%
journals.to_sql(name="journals", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
# Step 3: ARTICLES TABLE

# %%
# for converting to sql tables
all_articles_tools["journal_fk"]=0


for i in range(len(all_articles_tools)):
    if all_articles_tools["journal"][i] == "Nucleic Acids Research":
        all_articles_tools["journal_fk"][i]=1
    elif all_articles_tools["journal"][i] == "Bioinformatics Oxford":
        all_articles_tools["journal_fk"][i]=2
    elif all_articles_tools["journal"][i] == "BMC Bioinformatics":
        all_articles_tools["journal_fk"][i]=4
    elif all_articles_tools["journal"][i] == "Database Oxford":
        all_articles_tools["journal_fk"][i]=4
    i=i+1
# Out:
# /home/maayanlab/ENV/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
articles=all_articles_tools[["id", "link", "doi", "abstract", "title", "authors", "topics","tag", "citations_link", "references","date","info","journal_fk" ]]

# %%
articles = articles.rename(index=str, columns={"citations_link": "citation_link", "references": "article_references","info": "additional_info"})

# %%
articles
# Out:
#       id                                               link  \
# 0      1  https://academic.oup.com/database/article/3563...
# 1      2  https://academic.oup.com/database/article/4409...
# 2      3  https://academic.oup.com/database/article/2871...
# 3      4  https://academic.oup.com/database/article/2635...
# 4      5  https://academic.oup.com/database/article/2549...
# 5      6  https://academic.oup.com/database/article/3867...
# 6      7  https://academic.oup.com/database/article/3867...
# 18   10.1093/database/bax016
# 19   10.1093/database/bax015
# 20   10.1093/database/bax012
# 21   10.1093/database/bax009
# 22   10.1093/database/bax008
# 23   10.1093/database/bax001
# 24   10.1093/database/baw172
# 25   10.1093/database/baw171
# 26   10.1093/database/baw170
# 27   10.1093/database/baw167
# 28   10.1093/database/baw165
# 29   10.1093/database/baw160
# ..                       ...
# 303  10.1093/database/bar033
# 304  10.1093/database/bar032
# 305  10.1093/database/bar031
# 306  10.1093/database/bar029
# 307  10.1093/database/bar028
# 308  10.1093/database/bar025
# 309  10.1093/database/bar023
# 310  10.1093/database/bar018
# 311  10.1093/database/bar013
# 312  10.1093/database/bar009
# 313  10.1093/database/bar008
# 314  10.1093/database/baq039
# 315  10.1093/database/baq038
# 316  10.1093/database/baq037
# 317  10.1093/database/baq034
# 318  10.1093/database/baq033
# 319  10.1093/database/baq030
# 320  10.1093/database/baq023
# 321  10.1093/database/baq021
# 322  10.1093/database/baq019
# 323  10.1093/database/baq009
# 324  10.1093/database/baq005
# 325  10.1093/database/baq002
# 326  10.1093/database/bap026
# 327  10.1093/database/bap024
# 328  10.1093/database/bap022
# 329  10.1093/database/bap021
# 330  10.1093/database/bap016
# 331  10.1093/database/bap014
# 332  10.1093/database/bap003
#
#                                               abstract  \
# 0    The Gene Ontology (GO) has proven to be a valu...
# 1    The identification of novel candidate markers ...
# 2    To support a quantitative real-time polymerase...
# 3    Experience in clinical practice and research i...
# 4    One of the many roles of a toxicologist is to ...
# 5    Pigs are excellent large-animal models for med...
# 6    Leishmania braziliensisis the etiological agen...
# 7    Unraveling the genetic diversity held in geneb...
# 8    NutriChem is a database generated by text mini...
# 9    TIBLE is a web-based resource that provides ea...
# 10   As the generation and use of genomic datasets ...
# 11   BioM2MetDisease is a manually curated database...
# 12   The last decade has seen a surge in published ...
# 13   Triatomines are blood-sucking insects that tra...
# 14   Human diseases such as cancer are routinely ch...
# 15   With the advancement of genome-sequencing tech...
# 16   Knowing the position of protein structures wit...
# 17   The Gene Expression Database (GXD) is a compre...
# 18   Wastewater is increasingly viewed as a resourc...
# 19   The various pathophysiological processes occur...
# 20   Experimentally generated biological informatio...
# 21   Hop (Humulus lupulus L. var lupulus) is a dioe...
# 22   The volume of transcriptome data is growing ex...
# 23   Silkworm pathogens have been heavily impeding ...
# 24   The detection and identification of bacterial ...
# 25   Based on the current tools,de novosecretome (f...
# 26   Penicillium expansum, the causal agent of blue...
# 27   Protein association networks can be inferred f...
# 28   Antibiotic resistance (AR) is a major global p...
# 29   With its Firebrowse service (http://firebrowse...
# ..                                                 ...
# 303  The InterPro BioMart provides users with query...
# 304  We previously developed NetPath as a resource ...
# 305  Reactome is an open source, expert-authored, m...
# 306  Here, we describe the BioMart interface to the...
# 307  In this article, we describe the use of the Bi...
# 308  Expression microarrays are commonly used to st...
# 309  The model organism Encyclopedia of DNA Element...
# 310  Catalogue of Somatic Mutations in Cancer (COSM...
# 311  Many abbreviations are used in the literature ...
# 312  The UniProt Knowledgebase (UniProtKB) acts as ...
# 313  In recent years, genomes from an increasing nu...
# 314  TheCaenorhabditis elegansgenome sequence was p...
# 315  The CEREALAB database aims to store genotypic ...
# 316  The Biomolecular Interaction Network Database ...
# 317  The AthaMap database generates a map of potent...
# 318  Molecular dynamics simulations can now routine...
# 319  GermOnline 4.0 is a cross-species database por...
# 320  We present iRefWeb, a web interface to protein...
# 321  This article is a tutorial for PDBj Mine, a ne...
# 322  G-protein coupled receptors (GPCRs) are a majo...
# 323  The success of community projects such as Wiki...
# 324  Protein-trap strains ofDrosophila melanogaster...
# 325  The accumulation of complete genomic sequences...
# 326  Protein phosphorylation plays a central role i...
# 327  A number of databases on the plant metabolome ...
# 328  Ciliopathies, pleiotropic diseases provoked by...
# 329  The initial outcome of genome sequencing is th...
# 330  UniProtKB/Swiss-Prot, a curated protein databa...
# 331  Viruses, viroids and prions are the smallest i...
# 332  Results of the recent Critical Assessment of T...
#
#                                                  title  \
# 0    QuickGO: a user tutorial for the web-based Gen...
# 1    CancerMA: a web-based tool for automatic meta-...
# 2       RefPrimeCouch—a reference gene primer CouchApp
# 3    DCDB 2.0: a major update of the drug combinati...
# 4    ToxReporter: viewing the genome through the ey...
# 5    PigVar: a database of pig variations and posit...
# 6    LeishDB: a database of coding gene annotation ...
# 7    MGIS: managing banana (Musaspp.) genetic resou...
# 8    NutriChem 2.0: exploring the effect of plant-b...
# 9    TIBLE: a web-based, freely accessible resource...
# 10   GenomeHubs: simple containerized setup of a cu...
# 11   BioM2MetDisease: a manually curated database f...
# 12   CHOmine: an integrated data warehouse for CHO ...
# 13   TriatoKey: a web and mobile tool for biodivers...
# 14   NaviCom: a web application to create interacti...
# 15   WikiGenomes: an open web application for commu...
# 16   TMPL: a database of experimental and theoretic...
# 17   Effective biomedical document classification f...
# 18   MiDAS 2.0: an ecosystem-specific taxonomy and ...
# 19   miRnalyze: an interactive database linking too...
# 20   Strategies towards digital and semi-automated ...
# 21      HopBase: a unified resource forHumulusgenomics
# 22   Workflow and web application for annotating NC...
# 23   SilkPathDB: a comprehensive resource for the s...
# 24   OCaPPI-Db: an oligonucleotide probe database f...
# 25              VerSeDa: vertebrate secretome database
# 26   PCPPI: a comprehensive database for the predic...
# 27   RAIN: RNA–protein Association and Interaction ...
# 28   FARME DB: a functional antibiotic resistance e...
# 29   FirebrowseR: an R client to the Broad Institut...
# ..                                                 ...
# 303  The InterPro BioMart: federated query and web ...
# 304    NetSlim: high-confidence curated signaling maps
# 305                               The Reactome BioMart
# 306  The BioMart interface to the eMouseAtlas gene ...
# 307  BioMart as an integration solution for the Int...
# 308  SigReannot-mart: a query environment for expre...
# 309  The modENCODE Data Coordination Center: lesson...
# 310  Data mining using the Catalogue of Somatic Mut...
# 311  Allie: a database and a search service of abbr...
# 312  UniProt Knowledgebase: a hub of integrated pro...
# 313  CycADS: an annotation database system to ease ...
# 314  Methods and strategies for gene structure cura...
# 315  A genotypic and phenotypic information source ...
# 316  The Biomolecular Interaction Network Database ...
# 317  AthaMap-assisted transcription factor target g...
# 318  Bookshelf: a simple curation system for the st...
# 319  GermOnline 4.0 is a genomics gateway for germl...
# 320  iRefWeb: interactive analysis of consolidated ...
# 321  PDBj Mine: design and implementation of relati...
# 322  GPCRs, G-proteins, effectors and their interac...
# 323  PDBWiki: added value through community annotat...
# 324  BrainTrap: a database of 3D protein expression...
# 325  Gene-oriented ortholog database: a functional ...
# 326  PhosphoGRID: a database of experimentally veri...
# 327  Phenol-Explorer: an online comprehensive datab...
# 328   Cildb: a knowledgebase for centrosomes and cilia
# 329  MicroScope: a platform for microbial genome an...
# 330  Collaborative annotation of genes and proteins...
# 331  ORION-VIRCAT: a tool for mapping ICTV and NCBI...
# 332  Analysis of CASP8 targets, predictions and ass...
#
#                                                authors topics  \
# 0    Rachael P. Huntley,David Binns,Emily Dimmer,Da...   NULL
# 1    Julia Feichtinger,Ramsay J. McFarlane,Lee D. L...   NULL
# 2    Jascha Silbermann,Catrin Wernicke,Heike Pospis...   NULL
# 3    Yanbin Liu,Qiang Wei,Guisheng Yu,Wanxia Gai,Yo...   NULL
# 4                                          Mark Gosink   NULL
# 5    Zhong-Yin Zhou,Aimin Li,Newton O. Otecko,Yan-H...   NULL
# 6    Felipe Torres,Raúl Arias-Carrasco,José C. Cari...   NULL
# 7    Max Ruas,V. Guignon,G. Sempere,J. Sardos,Y. Hu...   NULL
# 8    Yueqiong Ni,Kasper Jensen,Irene Kouskoumvekaki...   NULL
# 9    Sony Malhotra,Grace Mugumbate,Tom L. Blundell,...   NULL
# 10   Richard J. Challis,Sujai Kumar,Lewis Stevens,M...   NULL
# 11   Yanjun Xu,Haixiu Yang,Tan Wu,Qun Dong,Zeguo Su...   NULL
# 12   Matthias P. Gerstl,Michael Hanscho,David E. Ru...   NULL
# 13   Luciana Márcia de Oliveira,Raissa Nogueira de ...   NULL
# 14   Mathurin Dorel,Eric Viara,Emmanuel Barillot,An...   NULL
# 15   Tim E. Putman,Sebastien Lelong,Sebastian Burgs...   NULL
# 16   Guillaume Postic,Yassine Ghouzam,Catherine Etc...   NULL
# 17   Xiangying Jiang,Martin Ringwald,Judith Blake,H...   NULL
# 18   Simon Jon McIlroy,Rasmus Hansen Kirkegaard,Bia...   NULL
# 19   Sankha Subhra Das,Mithun James,Sandip Paul,Nis...   NULL
# 20   Fabio Rinaldi,Oscar Lithgow,Socorro Gama-Castr...   NULL
# 21   Steven T. Hill,Ramcharan Sudarsanam,John Henni...   NULL
# 22   Roberto Vera Alvarez,Newton Medeiros Vidal,Gin...   NULL
# 23   Tian Li,Guo-Qing Pan,Charles R. Vossbrinck,Jin...   NULL
# 24   Cyrielle Gasc,Antony Constantin,Faouzi Jaziri,...   NULL
# 25   Ana R. Cortazar,José A. Oguiza,Ana M. Aransay,...   NULL
# 26   Junyang Yue,Danfeng Zhang,Rongjun Ban,Xiaojing...   NULL
# 27   Alexander Junge,Jan C. Refsgaard,Christian Gar...   NULL
# 28   James C. Wallace,Jesse A. Port,Marissa N. Smit...   NULL
# 29   Mario Deng,Johannes Brägelmann,Ivan Kryukov,Nu...   NULL
# ..                                                 ...    ...
# 303  Philip Jones,David Binns,Conor McMenamin,Craig...   NULL
# 304  Rajesh Raju,Vishalakshi Nanjappa,Lavanya Balak...   NULL
# 305  Robin A. Haw,David Croft,Christina K. Yung,Nel...   NULL
# 306  Peter Stevenson,Lorna Richardson,Shanmugasunda...   NULL
# 307  Darren J. Oakley,Vivek Iyer,William C. Skarnes...   NULL
# 308  François Moreews,Gaelle Rauffet,Patrice Dehais...   NULL
# 309  Nicole L. Washington,E. O. Stinson,Marc D. Per...   NULL
# 310  Rebecca Shepherd,Simon A. Forbes,David Beare,S...   NULL
# 311  Yasunori Yamamoto,Atsuko Yamaguchi,Hidemasa Bo...   NULL
# 312                 Michele Magrane,UniProt Consortium   NULL
# 313  Augusto F. Vellozo,Amélie S. Véron,Patrice Baa...   NULL
# 314  G.W. Williams,P.A. Davis,A.S. Rogers,T. Bieri,...   NULL
# 315  Justyna Milc,Antonio Sala,Sonia Bergamaschi,Ni...   NULL
# 316   Ruth Isserlin,Rashad A. El-Badrawi,Gary D. Bader   NULL
# 317              Lorenz Bülow,Yuri Brill,Reinhard Hehl   NULL
# 318  Shabana Vohra,Benjamin A. Hall,Daniel A. Holdb...   NULL
# 319  Aurélie Lardenois,Alexandre Gattiker,Olivier C...   NULL
# 320  Brian Turner,Sabry Razick,Andrei L. Turinsky,J...   NULL
# 321     Akira R. Kinjo,Reiko Yamashita,Haruki Nakamura   NULL
# 322  Venkata P. Satagopam,Margarita C. Theodoropoul...   NULL
# 323  Henning Stehr,Jose M. Duarte,Michael Lappe,Jon...   NULL
# 324  Seymour Knowles-Barley,Mark Longair,J Douglas ...   NULL
# 325            Meng-Ru Ho,Chun-houh Chen,Wen-chang Lin   NULL
# 326  Chris Stark,Ting-Cheng Su,Ashton Breitkreutz,P...   NULL
# 327  V. Neveu,J. Perez-Jiménez,F. Vos,V. Crespy,L. ...   NULL
# 328  Olivier Arnaiz,Agata Malinowska,Catherine Klot...   NULL
# 329  D. Vallenet,S. Engelen,D. Mornico,S. Cruveille...   NULL
# 330  P. Gaudet,L. Lane,P. Fey,A. Bridge,S. Poux,A. ...   NULL
# 331               Willy Valdivia-Granda,Francis Larson   NULL
# 332  ShuoYong Shi,Jimin Pei,Ruslan I. Sadreyev,Lisa...   NULL
#
#                   tag                                      citation_link  \
# 0            TUTORIAL  http://gateway.webofknowledge.com/gateway/Gate...
# 1       DATABASE TOOL  http://gateway.webofknowledge.com/gateway/Gate...
# 2    ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 3     DATABASE UPDATE  http://gateway.webofknowledge.com/gateway/Gate...
# 4       DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 5    ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 6       DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 7       DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 8       DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 9       DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 10      DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 11   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 12   TECHNICAL REPORT  https://scholar.google.com/scholar?q=related:h...
# 13   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 14   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 15   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 16   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 17   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
# 18    DATABASE UPDATE  http://gateway.webofknowledge.com/gateway/Gate...
# 19      DATABASE TOOL  https://scholar.google.com/scholar?q=related:h...
# 20   ORIGINAL ARTICLE  https://scholar.google.com/scholar?q=related:h...
#
# 330            NULL           4
# 331             app           4
# 332            NULL           4
#
# [333 rows x 13 columns]

# %%
articles.to_sql(name="articles", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
# Step 4: METRICS TABLE

# %%
metrics=all_articles_tools[["id", "views", "relative_views", "citations_amount", "citations_per_year", "altmetric_score" ]]

# %%
metrics = metrics.rename(index=str, columns={"citations_amount": "citations",  "altmetric_score" :"altmetric_fk"})

# %%
metrics["article_fk"]=all_articles_tools.id

# %%
metrics.to_sql(name="metrics", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
only_main_tools
# Out:
#      Unnamed: 0                                           homepage  \
# 0             0                       http://www.ebi.ac.uk/QuickGO
# 1             1                         http://www.cancerma.org.uk
# 2             2  http://www.ibm.com/developerworks/opensource/t...
# 3             3                    http://www.cls.zju.edu.cn/dcdb/
# 4             4             https://github.com/mgosink/ToxReporter
# 5             5                 http://www.ibiomedical.net/pigvar/
# 6             6                             http://www.leishdb.com
# 7             7               https://www.crop-diversity.org/mgis/
# 8             8          http://sbb.hku.hk/services/NutriChem-2.0/
# 9             9             http://www-cryst.bioc.cam.ac.uk/tible/
# 10           10                              http://GenomeHubs.org
# 11           11        http://www.bio-bigdata.com/BioM2MetDisease/
# 12           12                 https://github.com/chomine/chomine
# 13           13                  http://triatokey.cpqrr.fiocruz.br
# 14           14                           https://navicom.curie.fr
# 15           15                         http://www.wikigenomes.org
# 16           16                   http://www.dsimb.inserm.fr/TMPL/
# 17           17              http://www.informatics.jax.org/gxdlit
# 18           18                     http://www.midasfieldguide.org
# 19           19                            http://www.mirnalyze.in
# 20           20                      http://regulondb.ccg.unam.mx/
# 21           21                                 http://hopbase.org
# 22           22     http://www.ncbi.nlm.nih.gov/projects/physalis/
# 23           23                       http://silkpathdb.swu.edu.cn
# 24           24                          http://ocappidb.uca.works
# 25           25    http://genomics.cicbiogune.es/VerSeDa/index.php
# 26           26            http://bdg.hfut.edu.cn/pcppi/index.html
# 27           27                       http://rth.dk/resources/rain
# 28           28         http://staff.washington.edu/jwallace/farme
# 29           29           https://github.com/mariodeng/FirebrowseR
# ..          ...                                                ...
# 270         291                        http://www.ebi.ac.uk/pride/
# 271         292              http://ptbdb.cs.brown.edu/dbPTBv1.php
# 272         294            http://www.gramene.org/biomart/martview
# 273         296                          http://cellpedia.cbrc.jp/
# 274         297                      http://tripal.sourceforge.net
# 275         299                     http://caps.ncbs.res.in/3dswap
# 276         302  http://www.ncbi.nlm.nih.gov/CBBresearch/Yu/dow...
# 277         304                     http://www.netpath.org/netslim
# 278         308           http://sigreannot-mart.toulouse.inra.fr/
# 279         309                           http://www.modencode.org
# 280         311                             http://allie.dbcls.jp/
# 281         312                            http://www.uniprot.org/
# 282         313                            http://www.cycadsys.org
# 283         315   http://www.cerealab.unimore.it/jws/cerealab.jnlp
# 284         317               http://www.athamap.de/gene_ident.php
# 285         318              http://sbcb.bioch.ox.ac.uk/bookshelf/
# 286         319                         http://www.germonline.org/
# 287         320                        http://wodaklab.org/iRefWeb
# 288         321                               http://www.pdbj.org/
# 289         322                http://schneider.embl.de/human_gpdb
# 290         323                             http://www.pdbwiki.org
# 291         324             http://fruitfly.inf.ed.ac.uk/braintrap
# 292         325             http://www.ncbi.nlm.nih.gov/homologene
# 293         326                         http://www.phosphogrid.org
# 294         327                      http://www.phenol-explorer.eu
# 295         328                       http://cildb.cgm.cnrs-gif.fr
# 296         329         http://www.genoscope.cns.fr/agc/microscope
# 297         330                            http://www.uniprot.org/
# 298         331  http://www.orionbiosciences.com/research/orion...
# 299         332                     http://prodata.swmed.edu/CASP8
#
#      id_article ids_related_articles                        name_tool  \
# 0             1                 NULL                          QuickGO
# 1             2                 NULL                         CancerMA
# 2             3                 NULL                         CouchApp
# 3             4                 NULL                             DCDB
# 4             5                 NULL                      ToxReporter
# 5             6                 NULL                           PigVar
# 6             7                 NULL                          LeishDB
# 7             8                 NULL                             MGIS
# 8             9                 NULL                        NutriChem
# 9            10                 NULL                            TIBLE
# 10           11                 NULL                       GenomeHubs
# 11           12                 NULL                  BioM2MetDisease
# 12           13                 NULL                          CHOmine
# 13           14                 NULL                        TriatoKey
# 14           15                 NULL                          NaviCom
# 15           16                 NULL                      WikiGenomes
# 16           17                 NULL                             TMPL
# 17           18                 NULL                              GXD
# 18           19                 NULL                            MiDAS
# 19           20                [126]                        miRnalyze
# 20           21                 NULL                        RegulonDB
# 21           22                [269]                          HopBase
# 22           23                 NULL                             NCBI
# 23           24                 NULL                       SilkPathDB
# 24           25                 NULL                        OCaPPI-Db
# 25           26                 NULL                          VerSeDa
# 26           27                 NULL                            PCPPI
# 27           28                 NULL                             RAIN
# 28           29                 NULL                            FARME
# 29           30                 NULL                      FirebrowseR
# ..          ...                  ...                              ...
# 270         292                 NULL                            PRIDE
# 271         293                 NULL                            dbPTB
# 272         295                 NULL                          BioMart
# 273         297                 NULL                        CELLPEDIA
# 274         298                 NULL                           Tripal
# 275         300                 NULL                           3DSwap
# 276         303                 NULL                          ppiTrim
# 277         305                 NULL                          NetSlim
# 278         309                 NULL                  SigReannot-mart
# 279         310                 NULL                        modENCODE
# 280         312                 NULL                            Allie
# 281         313                 NULL                          UniProt
# 282         314                 NULL                           CycADS
# 283         316                 NULL                         CEREALAB
# 284         318                 NULL                 AthaMap-assisted
# 285         319                 NULL                        Bookshelf
# 286         320                 NULL                       GermOnline
# 287         321                 NULL                          iRefWeb
# 288         322                 NULL                             PDBj
# 289         323                 NULL                       human-gpDB
# 290         324                 NULL                          PDBWiki
# 291         325                 NULL                        BrainTrap
# 292         326                 NULL  Gene-oriented ortholog database
# 293         327                 NULL                      PhosphoGRID
# 294         328                 NULL                  Phenol-Explorer
# 295         329                 NULL                            Cildb
# 296         330                 NULL                       MicroScope
# 297         331                 NULL             UniProtKB/Swiss-Prot
# 298         332                 NULL                     ORION-VIRCAT
# 299         333                 NULL                            CASP8
#
#                                               abstract  citations_per_year  \
# 0    The Gene Ontology (GO) has proven to be a valu...                 0.0
# 1    The identification of novel candidate markers ...                 1.0
# 2    To support a quantitative real-time polymerase...                 0.0
# 3    Experience in clinical practice and research i...                 1.0
# 4    One of the many roles of a toxicologist is to ...                 0.0
# 5    Pigs are excellent large-animal models for med...                 0.0
# 6    Leishmania braziliensisis the etiological agen...                 0.0
# 7    Unraveling the genetic diversity held in geneb...                 0.0
# 8    NutriChem is a database generated by text mini...                 0.0
# 9    TIBLE is a web-based resource that provides ea...                 0.0
# 10   As the generation and use of genomic datasets ...                 0.0
# 11   BioM2MetDisease is a manually curated database...                 0.0
# 12   The last decade has seen a surge in published ...                 0.0
# 13   Triatomines are blood-sucking insects that tra...                 0.0
# 14   Human diseases such as cancer are routinely ch...                 0.0
# 15   With the advancement of genome-sequencing tech...                 0.0
# 16   Knowing the position of protein structures wit...                 0.0
# 17   The Gene Expression Database (GXD) is a compre...                 0.0
# 18   Wastewater is increasingly viewed as a resourc...                 1.0
# 19   The various pathophysiological processes occur...                 0.0
# 20   Experimentally generated biological informatio...                 0.0
# 21   Hop (Humulus lupulus L. var lupulus) is a dioe...                 0.0
# 22   The volume of transcriptome data is growing ex...                 0.0
# 23   Silkworm pathogens have been heavily impeding ...                 0.0
# 24   The detection and identification of bacterial ...                 0.0
# 25   Based on the current tools,de novosecretome (f...                 0.0
# 26   Penicillium expansum, the causal agent of blue...                 0.0
# 27   Protein association networks can be inferred f...                 0.0
# 28   Antibiotic resistance (AR) is a major global p...                 1.0
# 29   With its Firebrowse service (http://firebrowse...                 0.0
# ..                                                 ...                 ...
# 270  The PRoteomics IDEntifications (PRIDE) databas...                 2.0
# 271  Genome-wide association studies (GWAS) query t...                 2.0
# 272  Gramene is a well-established resource for pla...                 2.0
# 273  CELLPEDIA is a repository database for current...                 1.0
# 274  As the availability, affordability and magnitu...                 2.0
# 275  Three-dimensional domain swapping is a unique ...                 2.0
# 276  Robust advances in interactome analysis demand...                 1.0
# 277  We previously developed NetPath as a resource ...                 2.0
# 278  Expression microarrays are commonly used to st...                 0.0
# 279  The model organism Encyclopedia of DNA Element...                 2.0
# 280  Many abbreviations are used in the literature ...                 0.0
# 281  The UniProt Knowledgebase (UniProtKB) acts as ...                27.0
# 282  In recent years, genomes from an increasing nu...                 1.0
# 283  The CEREALAB database aims to store genotypic ...                 0.0
# 284  The AthaMap database generates a map of potent...                 2.0
# 285  Molecular dynamics simulations can now routine...                 0.0
# 286  GermOnline 4.0 is a cross-species database por...                 2.0
# 287  We present iRefWeb, a web interface to protein...                 4.0
# 288  This article is a tutorial for PDBj Mine, a ne...                 0.0
# 289  G-protein coupled receptors (GPCRs) are a majo...                 1.0
# 290  The success of community projects such as Wiki...                 1.0
# 291  Protein-trap strains ofDrosophila melanogaster...                 1.0
# 292  The accumulation of complete genomic sequences...                 0.0
# 293  Protein phosphorylation plays a central role i...                 3.0
# 294  A number of databases on the plant metabolome ...                20.0
# 295  Ciliopathies, pleiotropic diseases provoked by...                 2.0
# 296  The initial outcome of genome sequencing is th...                 6.0
# 297  UniProtKB/Swiss-Prot, a curated protein databa...                 0.0
# 298  Viruses, viroids and prions are the smallest i...                 0.0
# 299  Results of the recent Critical Assessment of T...                 1.0
#
#      relative_views   id  closets_neighbor_1    ...      \
# 0                 4    1                 258    ...
# 1                 4    2                 105    ...
# 2                 4    3                  23    ...
# 3                 6    4                 123    ...
# 4                 6    5                 254    ...
# 5                13    6                 114    ...
# 6                10    7                  28    ...
# 7                14    8                 275    ...
# 8                 9    9                 295    ...
# 9                 8   10                 235    ...
# 10               16   11                  37    ...
# 11               12   12                 226    ...
# 12               10   13                 126    ...
# 13               10   14                  91    ...
# 14               15   15                 147    ...
# 15               19   16                  21    ...
# 16                7   17                  52    ...
# 17                7   18                 242    ...
# 18               15   19                 113    ...
# 19               19   20                 169    ...
# 20               13   21                 266    ...
# 21               11   22                  11    ...
# 22               11   23                   3    ...
# 23               14   24                 228    ...
# 24                9   25                 196    ...
# 25               13   26                 186    ...
# 26               13   27                 148    ...
# 27               34   28                 148    ...
# 28               24   29                 172    ...
# 29               23   30                 230    ...
# ..              ...  ...                 ...    ...
# 270               4  271                 239    ...
# 271               4  272                  85    ...
# 272               4  273                  73    ...
# 273               5  274                 269    ...
# 274               4  275                   8    ...
# 275               4  276                  84    ...
# 276               4  277                 224    ...
# 277               4  278                 141    ...
# 278               4  279                  25    ...
# 279               4  280                  88    ...
# 280               4  281                 193    ...
# 281               7  282                  63    ...
# 282               4  283                  54    ...
# 283               4  284                  42    ...
# 284               4  285                 103    ...
# 285               4  286                  53    ...
# 286               4  287                 231    ...
# 287               5  288                 148    ...
# 288               4  289                 202    ...
# 289               4  290                 274    ...
# 290               4  291                  56    ...
# 291               5  292                 235    ...
# 292               4  293                 130    ...
# 293               4  294                 161    ...
# 294               6  295                 222    ...
# 295               5  296                 241    ...
# 296               5  297                 283    ...
# 297               4  298                 229    ...
# 298               4  299                 169    ...
# 299               4  300                  69    ...
#
#      similarity_neighbor_1  similarity_neighbor_2  similarity_neighbor_3  \
# 0                 0.263237               0.203288               0.122651
# 1                 0.248407               0.242710               0.161916
# 2                 0.187336               0.127142               0.113680
# 3                 0.370255               0.333599               0.211214
# 4                 0.093490               0.088224               0.076162
# 5                 0.199154               0.135058               0.121003
# 6                 0.174833               0.147861               0.145801
# 7                 0.239615               0.142512               0.123893
# 8                 0.255364               0.235556               0.211214
# 9                 0.323952               0.226674               0.128100
# 10                0.162381               0.161254               0.141477
# 11                0.181486               0.172520               0.168630
# 12                0.116146               0.114399               0.106728
# 13                0.077609               0.070469               0.070053
# 14                0.201419               0.166370               0.128172
# 15                0.128806               0.115879               0.112301
# 16                0.184390               0.167075               0.153061
# 17                0.159813               0.144568               0.135385
# 18                0.091277               0.082674               0.077104
# 19                0.245460               0.238137               0.212373
# 20                0.322219               0.252963               0.248982
# 21                0.119636               0.091645               0.091320
# 22                0.187336               0.168545               0.147485
# 23                0.384117               0.135943               0.129225
# 24                0.416466               0.283654               0.145079
# 25                0.106005               0.091473               0.085892
# 26                0.181044               0.161586               0.151385
# 27                0.216391               0.174833               0.165448
# 28                0.136458               0.116607               0.110780
# 29                0.138086               0.127142               0.117268
# ..                     ...                    ...                    ...
# 270               0.300417               0.098754               0.093561
# 271               0.328130               0.174027               0.150944
# 288 -4.510895   1.865679
# 289  2.924423   0.120195
# 290  2.520816   1.292017
# 291  0.164588   5.528275
# 292  4.969723  -3.434604
# 293  4.246779   6.401827
# 294  1.953987  10.409383
# 295  8.400771  -3.295124
# 296 -5.914513  -2.253497
# 297 -1.648596   1.895184
# 298 -0.099712  -9.514636
# 299 -3.465348   5.538742
#
# [300 rows x 23 columns]

# %%
# Step 5: TOOLS TABLE

# %%
tools= only_main_tools[["id", "homepage", "name_tool","id_article"]]

# %%
tools = tools.rename(index=str, columns={"id_article": "article_fk"})

# %%
tools.to_sql(name="tools", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
# Step 6: TOOL_GRAPHING TABLE

# %%
tool_graphing= only_main_tools[["id", "x", "y","z", "x_2d", "y_2d","relative_views","citations_per_year" ]]

# %%
tool_graphing = tool_graphing.rename(index=str, columns={"relative_views": "size_views", "citations_per_year": "color_citations"})

# %%
tool_graphing.to_sql(name="tool_graphing", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
# Step 7: SIMILAR TOOL TABLE

# %%
similar_tools=DataFrame(columns=["id", "main_tool", "similar_tool_fk", "similarity", "rank"])

# %%
only_main_tools[250:300]
# Out:
#      Unnamed: 0                                           homepage  \
# 250         266                  http://bws.iis.sinica.edu.tw/THOD
# 251         267                 http://bcgenex.centregauducheau.fr
# 252         269      https://www.niddkrepository.org/niddk/home.do
# 253         271                           http://www.ontogene.org/
# 254         274  http://www.ncbi.nlm.nih.gov/CBBresearch/Lu/Dem...
# 255         275                            http://www.wormbase.org
# 256         276                                 http://flybase.org
# 257         277                     http://www.agbase.msstate.edu/
# 258         278                     http://solaria.uab.es/eTumour/
# 259         279                              http://www.drpias.net
# 260         280                        http://sysbio.unl.edu/DFVF/
# 261         281                      http://www.phenol-explorer.eu
# 262         282                            http://www.MuteinDB.org
# 263         283                   http://www.ncbi.nlm.nih.gov/geo/
# 264         284                      http://haltorf.roucoulab.com/
# 265         285                            http://www.pharmgkb.org
# 266         286  http://www.bioinf.manchester.ac.uk/dbbrowser/P...
# 267         287                   http://decrypthon.igbmc.fr/msv3d
# 268         288              http://crdd.osdd.net/raghava/cppsite/
# 269         290    http://www.ncbi.nlm.nih.gov/CCDS/CcdsBrowse.cgi
# 270         291                        http://www.ebi.ac.uk/pride/
# 271         292              http://ptbdb.cs.brown.edu/dbPTBv1.php
# 272         294            http://www.gramene.org/biomart/martview
# 273         296                          http://cellpedia.cbrc.jp/
# 274         297                      http://tripal.sourceforge.net
# 275         299                     http://caps.ncbs.res.in/3dswap
# 276         302  http://www.ncbi.nlm.nih.gov/CBBresearch/Yu/dow...
# 277         304                     http://www.netpath.org/netslim
# 278         308           http://sigreannot-mart.toulouse.inra.fr/
# 279         309                           http://www.modencode.org
# 280         311                             http://allie.dbcls.jp/
# 281         312                            http://www.uniprot.org/
# 282         313                            http://www.cycadsys.org
# 283         315   http://www.cerealab.unimore.it/jws/cerealab.jnlp
# 284         317               http://www.athamap.de/gene_ident.php
# 285         318              http://sbcb.bioch.ox.ac.uk/bookshelf/
# 286         319                         http://www.germonline.org/
# 287         320                        http://wodaklab.org/iRefWeb
# 288         321                               http://www.pdbj.org/
# 289         322                http://schneider.embl.de/human_gpdb
# 290         323                             http://www.pdbwiki.org
# 291         324             http://fruitfly.inf.ed.ac.uk/braintrap
# 292         325             http://www.ncbi.nlm.nih.gov/homologene
# 293         326                         http://www.phosphogrid.org
# 294         327                      http://www.phenol-explorer.eu
# 295         328                       http://cildb.cgm.cnrs-gif.fr
# 296         329         http://www.genoscope.cns.fr/agc/microscope
# 297         330                            http://www.uniprot.org/
# 298         331  http://www.orionbiosciences.com/research/orion...
# 299         332                     http://prodata.swmed.edu/CASP8
#
#      id_article ids_related_articles                        name_tool  \
# 250         267                 NULL                            T-HOD
# 251         268                 NULL                bc-GenExMiner 3.0
# 252         270                 NULL                            NIDDK
# 253         272                 NULL                         OntoGene
# 254         275                 NULL                         PubTator
# 255         276                 NULL                         WormBase
# 256         277                [315]                          FlyBase
# 257         278                 NULL                           AgBase
# 258         279                 NULL                          eTUMOUR
# 259         280                 NULL                             PIAS
# 260         281                 NULL                             DFVF
# 261         282                 NULL              Phenol-Explorer 2.0
# 262         283                 NULL                         MuteinDB
# 263         284                 NULL                              GEO
# 264         285                 NULL                          HAltORF
# 265         286                 NULL                         PharmGKB
# 266         287                 NULL                           PRINTS
# 267         288                 NULL                            MSV3d
# 268         289                 NULL                          CPPsite
# 269         291                 NULL                             CCDS
# 270         292                 NULL                            PRIDE
# 271         293                 NULL                            dbPTB
# 272         295                 NULL                          BioMart
# 273         297                 NULL                        CELLPEDIA
# 274         298                 NULL                           Tripal
# 275         300                 NULL                           3DSwap
# 276         303                 NULL                          ppiTrim
# 277         305                 NULL                          NetSlim
# 278         309                 NULL                  SigReannot-mart
# 279         310                 NULL                        modENCODE
# 280         312                 NULL                            Allie
# 281         313                 NULL                          UniProt
# 282         314                 NULL                           CycADS
# 283         316                 NULL                         CEREALAB
# 284         318                 NULL                 AthaMap-assisted
# 285         319                 NULL                        Bookshelf
# 286         320                 NULL                       GermOnline
# 287         321                 NULL                          iRefWeb
# 288         322                 NULL                             PDBj
# 289         323                 NULL                       human-gpDB
# 290         324                 NULL                          PDBWiki
# 291         325                 NULL                        BrainTrap
# 292         326                 NULL  Gene-oriented ortholog database
# 293         327                 NULL                      PhosphoGRID
# 294         328                 NULL                  Phenol-Explorer
# 295         329                 NULL                            Cildb
# 296         330                 NULL                       MicroScope
# 297         331                 NULL             UniProtKB/Swiss-Prot
# 298         332                 NULL                     ORION-VIRCAT
# 299         333                 NULL                            CASP8
#
#                                               abstract  citations_per_year  \
# 250  Researchers are finding it more and more diffi...                 2.0
# 251  We recently developed a user-friendly web-base...                 3.0
# 252  The National Institute of Diabetes and Digesti...                 0.0
# 253  In this article, we describe the architecture ...                 1.0
# 254  Today’s biomedical research has become heavily...                 4.0
# 255  WormBase, dictyBase and The Arabidopsis Inform...                 2.0
# 256  FlyBase is the model organism database for Dro...                 0.0
# 257  AgBase provides annotation for agricultural ge...                 1.0
# 258  The eTUMOUR (eT) multi-centre project gathered...                 1.0
# 259  Druggable Protein–protein Interaction Assessme...                 1.0
# 260  Fungal pathogens cause various diseases for pl...                 1.0
# 261  Phenol-Explorer, launched in 2009, is the only...                 6.0
# 262  Mutational events as well as the selection of ...                 0.0
# 263  High-throughput experiments and bioinformatics...                 0.0
# 264  Human alternative open reading frames (HAltORF...                 2.0
# 265  The need for efficient text-mining tools that ...                 2.0
# 266  The PRINTS database, now in its 21st year, hou...                 5.0
# 267  The elucidation of the complex relationships l...                 2.0
# 268  Delivering drug molecules into the cell is one...                 8.0
# 269  The Consensus Coding Sequence (CCDS) collabora...                 3.0
# 270  The PRoteomics IDEntifications (PRIDE) databas...                 2.0
# 271  Genome-wide association studies (GWAS) query t...                 2.0
# 272  Gramene is a well-established resource for pla...                 2.0
# 273  CELLPEDIA is a repository database for current...                 1.0
# 274  As the availability, affordability and magnitu...                 2.0
# 275  Three-dimensional domain swapping is a unique ...                 2.0
# 276  Robust advances in interactome analysis demand...                 1.0
# 277  We previously developed NetPath as a resource ...                 2.0
# 278  Expression microarrays are commonly used to st...                 0.0
# 279  The model organism Encyclopedia of DNA Element...                 2.0
# 280  Many abbreviations are used in the literature ...                 0.0
# 281  The UniProt Knowledgebase (UniProtKB) acts as ...                27.0
# 282  In recent years, genomes from an increasing nu...                 1.0
# 283  The CEREALAB database aims to store genotypic ...                 0.0
# 284  The AthaMap database generates a map of potent...                 2.0
# 285  Molecular dynamics simulations can now routine...                 0.0
# 286  GermOnline 4.0 is a cross-species database por...                 2.0
# 287  We present iRefWeb, a web interface to protein...                 4.0
# 288  This article is a tutorial for PDBj Mine, a ne...                 0.0
# 289  G-protein coupled receptors (GPCRs) are a majo...                 1.0
# 290  The success of community projects such as Wiki...                 1.0
# 291  Protein-trap strains ofDrosophila melanogaster...                 1.0
# 292  The accumulation of complete genomic sequences...                 0.0
# 293  Protein phosphorylation plays a central role i...                 3.0
# 294  A number of databases on the plant metabolome ...                20.0
# 295  Ciliopathies, pleiotropic diseases provoked by...                 2.0
# 296  The initial outcome of genome sequencing is th...                 6.0
# 297  UniProtKB/Swiss-Prot, a curated protein databa...                 0.0
# 298  Viruses, viroids and prions are the smallest i...                 0.0
# 299  Results of the recent Critical Assessment of T...                 1.0
#
#      relative_views   id  closets_neighbor_1    ...     similarity_neighbor_1  \
# 250               4  251                 241    ...                  0.159394
# 251               4  252                 147    ...                  0.166153
# 252               4  253                 226    ...                  0.160107
# 253               4  254                 266    ...                  0.267910
# 254               5  255                 264    ...                  0.228386
# 255               5  256                 266    ...                  0.150336
# 256               4  257                 198    ...                  0.329873
# 257               4  258                   1    ...                  0.263237
# 258               4  259                 244    ...                  0.115922
# 259               4  260                 150    ...                  0.143582
# 260               4  261                 236    ...                  0.336713
# 261               5  262                 222    ...                  0.656160
# 262               4  263                 134    ...                  0.154242
# 263               4  264                 255    ...                  0.228386
# 264               4  265                 167    ...                  0.115715
# 265               4  266                  21    ...                  0.322219
# 266               4  267                 203    ...                  0.207951
# 267               4  268                 229    ...                  0.182541
# 291  0.613069 -2.001160 -4.139476               NULL  -5.220692 -4.108541
# 292 -1.002582 -1.414275  2.702999               NULL   1.645400 -2.087088
# 293  3.586500 -4.202501 -5.443716               NULL  -6.041308 -6.238990
# 294  1.325411  6.192195 -3.456071               NULL  -9.586506  3.370774
# 295 -2.101908  0.629994  1.987037               NULL   6.203482  5.258882
# 296 -0.576482  1.392372 -1.151807               NULL   3.701485 -2.710874
# 297  2.212688  2.909144 -2.901421               NULL  -1.536231 -2.742679
# 298 -4.442860  2.729673 -2.344421               NULL  -1.826686  7.709018
# 299 -0.112639 -0.032598 -5.557784               NULL  -8.147485 -0.132573
#
# [50 rows x 23 columns]

# %%
j=0 
k=1
for i in range(len(only_main_tools)):
    similar_tools.loc[j]=[k,only_main_tools["id"][i],only_main_tools["closets_neighbor_1"][i],only_main_tools["similarity_neighbor_1"][i],1] 
    j=j+1
    k=k+1
    similar_tools.loc[j]=[k,only_main_tools["id"][i],only_main_tools["closets_neighbor_2"][i],only_main_tools["similarity_neighbor_2"][i],2]
    j=j+1
    k=k+1
    similar_tools.loc[j]=[k,only_main_tools["id"][i],only_main_tools["closets_neighbor_3"][i],only_main_tools["similarity_neighbor_3"][i],3]
    j=j+1
    k=k+1
    similar_tools.loc[j]=[k,only_main_tools["id"][i],only_main_tools["closets_neighbor_4"][i],only_main_tools["similarity_neighbor_4"][i],4]
    j=j+1
    k=k+1

# %%
similar_tools.similar_tool_fk = similar_tools.similar_tool_fk.astype(np.int16)
similar_tools.id = similar_tools.id.astype(np.int16)
similar_tools.main_tool = similar_tools.main_tool.astype(np.int16)

# %%
#similar_tools

# %%
similar_tools.to_sql(name="similar_tools", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)

# %%
# STEP 8 RELATED ARTICLES TABLE

# %%
only_main_tools[40:50]
# Out:
#     Unnamed: 0                                           homepage  id_article  \
# 40          41                   http://www.multiomics.in/PvTFDB/          42
# 41          43                                http://ricebase.org          44
# 42          44            https://github.com/dongseop/bioc_viewer          45
# 43          45                http://fantom.gsc.riken.jp/5/sstar/          46
# 44          46  http://www.actrec.gov.in/pi-webpages/AmitDutt/...          47
# 45          48                                http://www.sinex.cl          49
# 46          49                  http://babar.unige.ch:8082/neXtA5          50
# 47          50               http://cosbi.ee.ncku.edu.tw/CoopTFD/          51
# 48          51  http://ikmlab.csie.ncku.edu.tw/CDR2015/AuDis.html          52
# 49          52                http://btm.tmu.edu.tw/metastasisway          53
#
#                   ids_related_articles  name_tool  \
# 40                                NULL     PvTFDB
# 41                                NULL   Ricebase
# 42                                NULL       BioC
# 43  [43, 193, 202, 198, 199, 208, 239]    FANTOM5
# 44                                NULL  TMC-SNPdb
# 45                                NULL      SinEx
# 46                                NULL     neXtA5
# 47                                NULL    CoopTFD
# 48                                NULL      AuDis
# 49                                NULL        MET
#
#                                              abstract  citations_per_year  \
# 40  The common bean [Phaseolus vulgaris(L.)] is on...                 0.0
# 41  Ricebase (http://ricebase.org) is an integrati...                 1.0
# 42  BioC is an XML-based format designed to provid...                 1.0
# 43  The Functional Annotation of the Mammalian Gen...                 0.0
# 44  Cancer is predominantly a somatic disease. A m...                 0.0
# 45  Eukaryotic genes are typically interrupted by ...                 0.0
# 46  The rapid increase in the number of published ...                 0.0
# 47  In eukaryotic cells, transcriptional regulatio...                 0.0
# 48  Diseases play central roles in many areas of b...                 0.0
# 49  Metastasis is the dissemination of a cancer/tu...                 0.0
#
#     relative_views  id  closets_neighbor_1    ...     similarity_neighbor_1  \
# 40               5  41                 240    ...                  0.409596
# 41               8  42                  95    ...                  0.243609
# 42               5  43                  38    ...                  0.571531
# 43               8  44                 171    ...                  0.177769
# 44               7  45                 105    ...                  0.197958
# 45               6  46                 144    ...                  0.144672
# 46               5  47                  21    ...                  0.204403
# 47               5  48                 209    ...                  0.242786
# 48               6  49                 192    ...                  0.150821
# 49               6  50                 177    ...                  0.227593
#
#     similarity_neighbor_2  similarity_neighbor_3  similarity_neighbor_4  \
# 40               0.303751               0.203191               0.199715
# 41               0.193329               0.145516               0.123893
# 42               0.448128               0.441007               0.187517
# 43               0.154895               0.141529               0.122595
# 44               0.188179               0.132216               0.106483
# 45               0.138597               0.094850               0.092609
# 46               0.156538               0.146852               0.141550
# 47               0.215987               0.186550               0.169818
# 48               0.148764               0.136910               0.132848
# 49               0.162956               0.142385               0.141517
#
#            x         y         z  closest_neighbors      x_2d      y_2d
# 40 -2.918648  1.545375 -2.712397               NULL  2.298618 -5.067349
# 41 -5.434827  4.532797  0.657300               NULL -3.478507 -8.738428
# 42  6.949994 -0.395692  1.605395               NULL  7.997144  4.366928
# 43 -4.549813  0.276889  1.601496               NULL -3.184093 -2.815247
# 44 -0.358968  5.557323  0.658242               NULL  5.373111 -0.306157
# 45  1.532948 -0.155607  5.000232               NULL  0.622996  1.100563
# 46  4.882441 -0.419443  0.134611               NULL  8.556031  0.851233
# 47 -2.607531 -0.071062 -5.598248               NULL  3.424370 -5.651183
# 48  5.258254  2.993942 -0.198015               NULL  8.624548 -0.191497
# 49  3.989409  3.463420  1.724543               NULL  7.617052  2.750413
#
# [10 rows x 23 columns]

# %%
#only_main_tools["ids_related_articles"]

# %%
related_articles=DataFrame(columns=["id", "tool_id", "related_article_fk"])

# %%
import re
paranthesis =re.compile('\[|\]')
k=0
for i in range(len(only_main_tools)):
    size_plus=len(related_articles)
    if only_main_tools["ids_related_articles"][i]=="NULL":
        pass
    else:
        related_list_as_string=only_main_tools["ids_related_articles"][i]
        test2=re.sub(paranthesis, "",related_list_as_string)
        related_list=[]
        related_list= test2.split(",")
        tool_id=only_main_tools["id"][i]
        j=0
        while j < len(related_list):
            related_articles.loc[k]=[k+1, tool_id,related_list[j]]
            j=j+1
            k=k+1
    i=i+1

# %%
type(related_articles.related_articles_fk[1])
# Out:
# numpy.int16

# %%
related_articles.tool_id = related_articles.tool_id.astype(np.int16)
related_articles.id = related_articles.id.astype(np.int16)
related_articles.related_article_fk = related_articles.related_article_fk.astype(np.int16)

# %%
related_articles.to_sql(name="related_articles", con=engine, flavor=None, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None)
